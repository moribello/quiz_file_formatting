# %%
import pandas as pd
import numpy as np

# %%
print(pd.read_csv('data.csv', line_terminator='\n'))

# %%
file_input = open('chapter17.txt','r')
answers = pd.read_csv('chapter17_answers.txt')
array = np.array(file_input.readlines())
newarray = np.resize(array, (20,6))
df = pd.DataFrame(newarray, columns=['question', 'ans1', 'ans2', 'ans3', 'ans4', 'correct'])

# %%
for i in df.index:
    if df.loc[i,'question'][1] == ".":
        df.loc[i,'question'] = (str(df.loc[i,'question'])[2:-6])+"\n"
    else:
        df.loc[i,'question'] = str(df.loc[i,'question'])[3:-6] + "\n"
    df.loc[i,'correct'] = "ANSWER: " + answers.loc[i][1].strip() + '\n'
#    df.loc[i,'ans1'] = str(df.loc[i,'ans1'])[2:]
#    df.loc[i,'ans2'] = str(df.loc[i,'ans2'])[2:]
#    df.loc[i,'ans3'] = str(df.loc[i,'ans3'])[2:]
#    df.loc[i,'ans4'] = str(df.loc[i,'ans4'])[2:]

# %%
df
# Out:
#                                              question  \
# 0   ze-up is an ongoing evaluation of what has hap...
# 1   at is the most critical area of the scene that...
# 2    technical rescue situations, a Fire Fighter I...
# 3   e primary hazard for rescuers at a __ incident...
# 4   ich structural collapse pattern is the least l...
# 5   at is required for personnel working within 10...
# 6   en responding to any situation involving elect...
# 7   ich power source has the advantage of being av...
# 8   ich stabilization tool consists of wooden or p...
# 9   ich power saw is versatile, has a short, strai...
# 10  ich tools are air-pressurized devices that giv...
# 11  ich pulling tool is typically mounted on the f...
# 12  e common term for the area of the vehicle that...
# 13  ich type of vehicle frame is used on heavy-dut...
# 14  at is the primary hazard at vehicle extricatio...
# 15  ere should apparatus be parked at a vehicle ex...
# 16  at is used to prevent horizontal movement of a...
# 17  ich passenger safety system deploys air bags f...
# 18  r which type of glass will the lower corner br...
# 19  moving the doors and roof from a unibody const...
#
#                                                  ans1  \
# 0   A. how the incident compares to similar incide...
# 1                                        A. Hotzone\n
# 2                A. to plan operational procedures.\n
# 3                                    A. rope rescue\n
# 4                                        A. A-frame\n
# 5                                       A. Wet suit\n
# 6                 A. evacuate all nearby occupants.\n
# 7                                       A. Electric\n
# 8                              A. Shoring materials\n
# 9                                   A. Circular saw\n
# 10                               A. Hydraulic jacks\n
# 11                                         A. Winch\n
# 12                                         A. rear.\n
# 13                                       A. Unibody\n
# 14                                          A. Fire\n
# 15              A. Wherever there is adequate space\n
# 16                                         A. Jacks\n
# 17                 A. Head Protection Systems (HPS)\n
# 18                                  A. Safety glass\n
# 19    A. should only be done if vehicle is upright.\n
#
#                                                  ans2  \
# 0   B. whether incident costs incurred will be too...
# 1                                      B. Cold zone\n
# 2       B. to serve on the rapid intervention crew.\n
# 3                                  B. trench rescue\n
# 4                                        B. Lean-to\n
# 5                                   B. Dock bumpers\n
# 6                B. initiate mutual aid agreements.\n
# 7                                        B. Propane\n
# 8                             B. Cribbing materials\n
# 9                                    B. Whizzer saw\n
# 10                            B. Cribbing materials\n
# 11                                        B. Tripod\n
# 12                                        B. front.\n
# 13                                   B. Multi-frame\n
# 14                                       B. Traffic\n
# 15        B. As far off the shoulder as is possible\n
# 16                                  B. Wheel chocks\n
# 17         B. Side-Impact Protection Systems (SIPS)\n
# 18                                B. Tempered glass\n
# 19   B. has minimal impact on structural integrity.\n
#
#                                                  ans3  \
# 0   C. what resources will be needed to resolve th...
# 1                                      C. Warm zone\n
# 2    C. primarily to assist the technical rescuers.\n
# 3                           C. water and ice rescue\n
# 4                                        C. Pancake\n
# 5                                  C. Two-way radio\n
# 6      C. call for the electric company to respond.\n
# 7                                      C. Hydraulic\n
# 8                        C. Cable and block systems\n
# 9                              C. Reciprocating saw\n
# 10                     C. Pneumatic lifting devices\n
# 11                               C. Buttress system\n
# 12                                     C. interior.\n
# 13                                   C. Space frame\n
# 14                           C. Hazardous materials\n
# 15  C. On the opposite side of the roadway as the ...
# 16                         C. High-pressure cushion\n
# 17  C. Extendable Roll Over Protection Systems (RO...
# 18                               C. Composite glass\n
# 19  C. should only be done if vehicle is on its si...
#
#                                                  ans4      correct
# 0   D. what other types of calls may stretch resou...  ANSWER: C\n
# 1                                 D. Command center\n  ANSWER: A\n
# 2   D. to perform the same skills as technical res...  ANSWER: C\n
# 3                          D. confined-space rescue\n  ANSWER: A\n
# 4                                     D. Cantilever\n  ANSWER: C\n
# 5                D. Personal flotation device (PFD)\n  ANSWER: D\n
# 6      D. begin extrication operations immediately.\n  ANSWER: C\n
# 7                                      D. Pneumatic\n  ANSWER: A\n
# 8                     D. Tensioned buttress systems\n  ANSWER: B\n
# 9                              D. Rotary rescue saw\n  ANSWER: C\n
# 10                     D. Tensioned buttress system\n  ANSWER: C\n
# 11                                D. Extension rams\n  ANSWER: A\n
# 12                                D. driver's side.\n  ANSWER: B\n
# 13                           D. Full or rigid frame\n  ANSWER: D\n
# 14                      D. Environmental conditions\n  ANSWER: B\n
# 15  D. So that the apparatus forms a protective ba...  ANSWER: D\n
# 16                    D. Tensioned buttress systems\n  ANSWER: B\n
# 17  D. Supplemental Passenger Restraint Systems (S...  ANSWER: A\n
# 18                        D. Doubly laminated glass\n  ANSWER: B\n
# 19  D. can seriously compromise its structural int...  ANSWER: D\n

# %%
text_array = df.to_numpy()
np.savetxt('test.txt', text_array, delimiter=" ", fmt="%s")
