# %%
import pandas as pd
import numpy as np

# %%
file_input = open("chapter17.txt",'r')
array = np.array(file_input.readlines())
newarray = np.resize(array, (15,6))
# Out:
#                                              question  \
# 0   1. Size-up is an ongoing evaluation of what ha...
# 1   2. What is the most critical area of the scene...
# 2   3. In technical rescue situations, a Fire Figh...
# 3   4. The primary hazard for rescuers at a __ inc...
# 4   5. Which structural collapse pattern is the le...
# 5   6. What is required for personnel working with...
# 6   7. When responding to any situation involving ...
# 7   8. Which power source has the advantage of bei...
# 8   9. Which stabilization tool consists of wooden...
# 9   10. Which power saw is versatile, has a short,...
# 10  11. Which tools are air-pressurized devices th...
# 11  12. Which pulling tool is typically mounted on...
# 12  13. The common term for the area of the vehicl...
# 13  14. Which type of vehicle frame is used on hea...
# 14  15. What is the primary hazard at vehicle extr...
#
#                                                  ans1  \
# 0   A. how the incident compares to similar incide...
# 1                                        A. Hotzone\n
# 2                A. to plan operational procedures.\n
# 3                                    A. rope rescue\n
# 4                                        A. A-frame\n
# 5                                       A. Wet suit\n
# 6                 A. evacuate all nearby occupants.\n
# 7                                       A. Electric\n
# 8                              A. Shoring materials\n
# 9                                   A. Circular saw\n
# 10                               A. Hydraulic jacks\n
# 11                                         A. Winch\n
# 12                                         A. rear.\n
# 13                                       A. Unibody\n
# 14                                          A. Fire\n
#
#                                                  ans2  \
# 0   B. whether incident costs incurred will be too...
# 1                                      B. Cold zone\n
# 2       B. to serve on the rapid intervention crew.\n
# 3                                  B. trench rescue\n
# 4                                        B. Lean-to\n
# 5                                   B. Dock bumpers\n
# 6                B. initiate mutual aid agreements.\n
# 7                                        B. Propane\n
# 8                             B. Cribbing materials\n
# 9                                    B. Whizzer saw\n
# 10                            B. Cribbing materials\n
# 11                                        B. Tripod\n
# 12                                        B. front.\n
# 13                                   B. Multi-frame\n
# 14                                       B. Traffic\n
#
#                                                  ans3  \
# 0   C. what resources will be needed to resolve th...
# 1                                      C. Warm zone\n
# 2    C. primarily to assist the technical rescuers.\n
# 3                           C. water and ice rescue\n
# 4                                        C. Pancake\n
# 5                                  C. Two-way radio\n
# 6      C. call for the electric company to respond.\n
# 7                                      C. Hydraulic\n
# 8                        C. Cable and block systems\n
# 9                              C. Reciprocating saw\n
# 10                     C. Pneumatic lifting devices\n
# 11                               C. Buttress system\n
# 12                                     C. interior.\n
# 13                                   C. Space frame\n
# 14                           C. Hazardous materials\n
#
#                                                  ans4 correct
# 0   D. what other types of calls may stretch resou...      \n
# 1                                 D. Command center\n      \n
# 2   D. to perform the same skills as technical res...      \n
# 3                          D. confined-space rescue\n      \n
# 4                                     D. Cantilever\n      \n
# 5                D. Personal flotation device (PFD)\n      \n
# 6      D. begin extrication operations immediately.\n      \n
# 7                                      D. Pneumatic\n      \n
# 8                     D. Tensioned buttress systems\n      \n
# 9                              D. Rotary rescue saw\n      \n
# 10                     D. Tensioned buttress system\n      \n
# 11                                D. Extension rams\n      \n
# 12                                D. driver's side.\n      \n
# 13                           D. Full or rigid frame\n      \n
# 14                      D. Environmental conditions\n      \n

# %%
for i in newarray.index:
    if df.loc[i,'question'][1] == ".":
        df.loc[i,'question'] = str(df.loc[i,'question'])[2:]
    else:
        df.loc[i,'question'] = str(df.loc[i,'question'])[3:]
    df.loc[i,'ans1'] = str(df.loc[i,'ans1'])[2:]
    df.loc[i,'ans2'] = str(df.loc[i,'ans2'])[2:]
    df.loc[i,'ans3'] = str(df.loc[i,'ans3'])[2:]
    df.loc[i,'ans4'] = str(df.loc[i,'ans4'])[2:]

# %%
df
# Out:
#                                              question  \
# 0    Size-up is an ongoing evaluation of what has ...
# 1    What is the most critical area of the scene t...
# 2    In technical rescue situations, a Fire Fighte...
# 3    The primary hazard for rescuers at a __ incid...
# 4    Which structural collapse pattern is the leas...
# 5    What is required for personnel working within...
# 6    When responding to any situation involving el...
# 7    Which power source has the advantage of being...
# 8    Which stabilization tool consists of wooden o...
# 9    Which power saw is versatile, has a short, st...
# 10   Which tools are air-pressurized devices that ...
# 11   Which pulling tool is typically mounted on th...
# 12   The common term for the area of the vehicle t...
# 13   Which type of vehicle frame is used on heavy-...
# 14   What is the primary hazard at vehicle extrica...
#
#                                                  ans1  \
# 0    how the incident compares to similar incident...
# 1                                           Hotzone\n
# 2                   to plan operational procedures.\n
# 3                                       rope rescue\n
# 4                                           A-frame\n
# 5                                          Wet suit\n
# 6                    evacuate all nearby occupants.\n
# 7                                          Electric\n
# 8                                 Shoring materials\n
# 9                                      Circular saw\n
# 10                                  Hydraulic jacks\n
# 11                                            Winch\n
# 12                                            rear.\n
# 13                                          Unibody\n
# 14                                             Fire\n
#
#                                                  ans2  \
# 0    whether incident costs incurred will be too h...
# 1                                         Cold zone\n
# 2          to serve on the rapid intervention crew.\n
# 3                                     trench rescue\n
# 4                                           Lean-to\n
# 5                                      Dock bumpers\n
# 6                   initiate mutual aid agreements.\n
# 7                                           Propane\n
# 8                                Cribbing materials\n
# 9                                       Whizzer saw\n
# 10                               Cribbing materials\n
# 11                                           Tripod\n
# 12                                           front.\n
# 13                                      Multi-frame\n
# 14                                          Traffic\n
#
#                                                  ans3  \
# 0    what resources will be needed to resolve the ...
# 1                                         Warm zone\n
# 2       primarily to assist the technical rescuers.\n
# 3                              water and ice rescue\n
# 4                                           Pancake\n
# 5                                     Two-way radio\n
# 6         call for the electric company to respond.\n
# 7                                         Hydraulic\n
# 8                           Cable and block systems\n
# 9                                 Reciprocating saw\n
# 10                        Pneumatic lifting devices\n
# 11                                  Buttress system\n
# 12                                        interior.\n
# 13                                      Space frame\n
# 14                              Hazardous materials\n
#
#                                                  ans4 correct
# 0    what other types of calls may stretch resourc...      \n
# 1                                    Command center\n      \n
# 2    to perform the same skills as technical rescu...      \n
# 3                             confined-space rescue\n      \n
# 4                                        Cantilever\n      \n
# 5                   Personal flotation device (PFD)\n      \n
# 6         begin extrication operations immediately.\n      \n
# 7                                         Pneumatic\n      \n
# 8                        Tensioned buttress systems\n      \n
# 9                                 Rotary rescue saw\n      \n
# 10                        Tensioned buttress system\n      \n
# 11                                   Extension rams\n      \n
# 12                                   driver's side.\n      \n
# 13                              Full or rigid frame\n      \n
# 14                         Environmental conditions\n      \n
